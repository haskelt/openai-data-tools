# %% [markdown]
# ## Checking if two names match
# This demo shows how you can take two names and test whether they are equivalent, despite superficial differences.
#
# This is a challenging problem because any given name can be written in a number of ways. For example, 'Jennifer L. Chen' could potentially match any of the
# following:
# * Jennifer Chen
# * Chen, Jennifer
# * Jenny Chen
# * Jenny L. Chen
# * Jennifer Lilian Chen
# * CHEN, Jennifer L.

# %%
import os
import json
import pickle
import pandas as pd
import numpy as np

# %%
import sys
sys.path.append('../..')
import openai_data_tools as dt

# %%
names = pd.read_csv('names.csv', dtype=str, keep_default_na=False)

# %% [markdown]
# Here is our test data set: name1 and name2 are the names to be matched, target is the desired output (1 for match, 0 for no match).

# %%
names
# Out:
#                       name1                  name2 target order nickname case  \
# 0             Alice Wilkins          Alice Wilkins      1
# 1           Charles Dillard            John Graham      0
# 2             Jennifer Chen             Jenny Chen      1              1
# 3                Darcy Reed             Greta Reed      0
# 4             George Wilson         Wilson, George      1     1
# 5              Jimmy Hutton           James Hutton      1              1
# 6         Benedict, Alfonso        DeNiro, Alfonso      0
# 7              Henry Garcia            Hank Garcia      1              1
# 8           Reginald Potter        Morrison, Draco      0     1
# 9      Sheeran, Christopher       Purcell, Charlie      0
# 10             Peggy Flores        Margaret Flores      1              1
# 11              Kris Garner       Garner, Kristine      1     1        1
# 12       Romanov, Anastasia        Romanov, Alexei      0
# 13            Choi Duck-soo           Santosh Modi      0
# 14            Shinzo Kimura         KIMURA, SHINZO      1     1             1
# 15           Harry S. Brown            Harry Brown      1
# 16      Natalie G. Sorensen    Natalie L. Sorensen      0
# 17           John F. Keaton  John Frederick Keaton      1
# 18           Ronald J Olmos        Ronald J. Olmos      1
# 19             Ghali, Bobby           Ghali, Billy      0
# 20            BOBBY OLAFSON        Olafson, Robert      1     1        1    1
# 21       Madison J. Richter       Reinholtz, Maddy      0     1        1
# 22  Kingston, Thomas Miller           Tom Kingston      1     1        1
# 23     Winston Percival Sr.   Winston Percival Jr.      0
# 24         Leonard van Pelt      van Pelt, Leonard      1     1
# 25       Jackie Rose-Garcia      Jackie RoseGarcia      1
# 26         Julio San Marcos      San Marcos, Julio      1     1
# 27         Geert van Houten     von Neumann, Tracy      0     1
# 28   Acker-Johnson, Barbara     Barbara T. Johnson      0     1
# 29        MICHAEL TOMASELLO        Tomlinson, Mike      0     1        1    1
# 30        L. Scott Grosjean         Scott Grosjean      1
# 31       Gunderson, Brianna          Bri Henderson      0     1        1
# 32       North-Palin, Julia      Julie North-Palin      1     1        1
# 33              Smith, Kara           Smithe, Cara      0
# 34              LAURA TRENT        LAURIE V. TRENT      1              1
# 35  Hernandez, Guadalupe M.        Hernandez, Lupe      1              1
# 36         VERONICA SANCHEZ          Sanchez, Vero      1     1        1    1
# 37           Roberto Torres            Beto Torres      1              1
# 38          ORTEGA, LORENZO        ORTEGO, LOURDES      0
# 39            Manuel Moreno         Manolo Morales      0              1
# 40             Francis Bond           FRANCIS BOND      1                   1
# 41         Brent Cummingham            HERTZ, JILL      0     1        1    1
# 42         Niles Reed Heath        Patty Reed Horn      0
# 43       Tess-Davies, Elena    Dutton-Wells, Elena      0
#
#    middle partial suffix multiword hyphen
# 0
# 1
# 2
# 3               1
# 4
# 5
# 6               1
# 7
# 8
# 9
# 10
# 11
# 12              1
# 13
# 14
# 15      1
# 16      1
# 17      1
# 18      1
# 19              1
# 20
# 21      1       1
# 22      1
# 23                     1
# 24                               1
# 25                                      1
# 26                               1
# 27              1                1
# 28      1       1                1      1
# 29              1
# 30      1
# 31              1
# 32                                      1
# 33              1
# 34      1
# 35      1
# 36
# 37
# 38              1
# 39              1
# 40
# 41
# 42      1       1
# 43              1                       1

# %% [markdown]
# The input to the model needs to be a string, so for each of our test items, we add both names to a JSON structure and then stringify it.

# %%
names_json = [json.dumps({"name1": row['name1'], "name2": row['name2']}) for index, row in names.iterrows()]

# %% [markdown]
# In our instructions, we ask the model to return 1 for a match, and 0 for a mismatch. We also give specific instructions on how to handle the ordering of first and last name, as well as middle names.

# %%
processor = dt.DataProcessor(
    api_key=os.getenv("OPENAI_API_KEY"),
    model = 'gpt-3.5-turbo', 
    instructions = "You will be provided with a JSON object with two keys, 'name1' and 'name2'. If the two names are equivalent, return the value '1'. If they are different, return '0'. Treat nicknames as equivalent to the full name. Treat <last name>, <first name> as equivalent to <firstname> <lastname>. If both names have middle names or middle initials, they should match for the names to be equivalent. If only one name has a middle name or middle initial, ignore it."
)

# %% [markdown]
# The GPT models are not deterministic, meaning that they won't necessarily give you the same answer each time. To get more consistent results, we do multiple runs through the test items, and then use the most common response as the output (more on that below).

# %%
outputs = []
for run in range(1,6):
    print(f'Run {run}')
    output = processor.process(names_json)
    outputs.append(output)
# Out:
# Run 1
# Progress: 100%
# Run 2
# Progress: 100%
# Run 3
# Progress: 100%
# Run 4
# Progress: 100%
# Run 5
# Progress: 100%

# %% [markdown]
# It is useful to be able to save the model output so we can continue analysis in a later session. The pickle library provides an easy way to do this.

# %%
with open('output_pickle', 'wb') as outfile:
    pickle.dump(outputs, outfile)

# %% [markdown]
# We can then load the output again like this:

# %%
with open('output_pickle', 'rb') as infile:
    output = pickle.load(infile)

# %% [markdown]
# A `RunAggregator` is used to process output values from multiple runs of the model. We can use it to calculate the level of agreement across runs.

# %%
aggregator = dt.RunAggregator(outputs)
aggregator.agreement()
# Out:
# 0.8181818181818181

# %% [markdown]
# We can also use it to produce a single set of output values based on the most common response for each item. We can then score the model based on those output values.

# %%
combined_output = aggregator.output()
scorer = dt.Scorer(combined_output, names['target'])
scorer.accuracy()
# Out:
# 0.9090909090909091

# %% [markdown]
# In this demo the model outputs are 0's and 1's, so we can also calculate the average output for each item. That lets us see whether the output was consistent (average is 0 or 1) or variable (average in between 0 and 1).

# %%
avg_output = np.mean(np.array(outputs,dtype=int),axis=0).tolist()

# %% [markdown]
# The code below shows a breakdown of how the model did for each item. The `scores` method returns a list with 1 if the model output matches the target, and 0 if it doesn't.

# %%
scores = scorer.scores()
pd.DataFrame({'name1': names['name1'], 'name2': names['name2'], 'target': names['target'], 'output': combined_output, 'score': scores, 'avg_output': avg_output})
# Out:
#                       name1                  name2 target output  score  \
# 0             Alice Wilkins          Alice Wilkins      1      1      1
# 1           Charles Dillard            John Graham      0      0      1
# 2             Jennifer Chen             Jenny Chen      1      1      1
# 3                Darcy Reed             Greta Reed      0      0      1
# 4             George Wilson         Wilson, George      1      1      1
# 5              Jimmy Hutton           James Hutton      1      1      1
# 6         Benedict, Alfonso        DeNiro, Alfonso      0      0      1
# 7              Henry Garcia            Hank Garcia      1      1      1
# 8           Reginald Potter        Morrison, Draco      0      0      1
# 9      Sheeran, Christopher       Purcell, Charlie      0      0      1
# 10             Peggy Flores        Margaret Flores      1      1      1
# 11              Kris Garner       Garner, Kristine      1      1      1
# 12       Romanov, Anastasia        Romanov, Alexei      0      0      1
# 13            Choi Duck-soo           Santosh Modi      0      0      1
# 14            Shinzo Kimura         KIMURA, SHINZO      1      1      1
# 15           Harry S. Brown            Harry Brown      1      1      1
# 16      Natalie G. Sorensen    Natalie L. Sorensen      0      1      0
# 17           John F. Keaton  John Frederick Keaton      1      1      1
# 18           Ronald J Olmos        Ronald J. Olmos      1      1      1
# 19             Ghali, Bobby           Ghali, Billy      0      0      1
# 20            BOBBY OLAFSON        Olafson, Robert      1      0      0
# 21       Madison J. Richter       Reinholtz, Maddy      0      0      1
# 22  Kingston, Thomas Miller           Tom Kingston      1      0      0
# 23     Winston Percival Sr.   Winston Percival Jr.      0      0      1
# 24         Leonard van Pelt      van Pelt, Leonard      1      1      1
# 25       Jackie Rose-Garcia      Jackie RoseGarcia      1      1      1
# 26         Julio San Marcos      San Marcos, Julio      1      1      1
# 27         Geert van Houten     von Neumann, Tracy      0      0      1
# 28   Acker-Johnson, Barbara     Barbara T. Johnson      0      0      1
# 29        MICHAEL TOMASELLO        Tomlinson, Mike      0      0      1
# 30        L. Scott Grosjean         Scott Grosjean      1      1      1
# 31       Gunderson, Brianna          Bri Henderson      0      0      1
# 32       North-Palin, Julia      Julie North-Palin      1      1      1
# 33              Smith, Kara           Smithe, Cara      0      0      1
# 34              LAURA TRENT        LAURIE V. TRENT      1      0      0
# 35  Hernandez, Guadalupe M.        Hernandez, Lupe      1      1      1
# 36         VERONICA SANCHEZ          Sanchez, Vero      1      1      1
# 37           Roberto Torres            Beto Torres      1      1      1
# 38          ORTEGA, LORENZO        ORTEGO, LOURDES      0      0      1
# 39            Manuel Moreno         Manolo Morales      0      0      1
# 40             Francis Bond           FRANCIS BOND      1      1      1
# 41         Brent Cummingham            HERTZ, JILL      0      0      1
# 42         Niles Reed Heath        Patty Reed Horn      0      0      1
# 43       Tess-Davies, Elena    Dutton-Wells, Elena      0      0      1
#
#     avg_output
# 0          1.0
# 1          0.0
# 2          1.0
# 3          0.2
# 4          1.0
# 5          0.6
# 6          0.0
# 7          0.6
# 8          0.0
# 9          0.0
# 10         0.8
# 11         0.6
# 12         0.0
# 13         0.0
# 14         0.8
# 15         0.8
# 16         0.6
# 17         1.0
# 18         1.0
# 19         0.4
# 20         0.4
# 21         0.0
# 22         0.0
# 23         0.0
# 24         1.0
# 25         1.0
# 26         1.0
# 27         0.0
# 28         0.0
# 29         0.0
# 30         0.8
# 31         0.0
# 32         0.6
# 33         0.0
# 34         0.2
# 35         0.6
# 36         1.0
# 37         0.8
# 38         0.0
# 39         0.0
# 40         1.0
# 41         0.0
# 42         0.0
# 43         0.2
